# %% [markdown]
# # int

# %%
adad = 15
print(type(adad))
print(adad)
# Out:
# <class 'int'>
# 15

# %% [markdown]
# float

# %%
pi = 3.14
print(type(pi))
print(pi)
# Out:
# <class 'float'>
# 3.14

# %% [markdown]
# string

# %%
name = 'mohsen'
print(type(name))
print(name)
# Out:
# <class 'str'>
# mohsen

# %% [markdown]
# list

# %%
animals = ['cat', 'dog', 'rabbit', 'khar', 23, 3.14, [1, 2, 3]]
print(type(animals))
print(animals)
# Out:
# <class 'list'>
# ['cat', 'dog', 'rabbit', 'khar', 23, 3.14, [1, 2, 3]]

# %% [markdown]
# dic

# %%
phone_book = {
    'Alice': '123-456-7890',
    'Bob': '987-654-3210',
    'Charlie': '555-555-5555'
}

# %% [markdown]
# tuple

# %%
size = (23, 12.5)
print(type(size))
print(size)
# Out:
# <class 'tuple'>
# (23, 12.5)

# %% [markdown]
# boolean

# %%
state = False
print(type(state))
print(state)
# Out:
# <class 'bool'>
# False

# %% [markdown]
# <
# >
# ==
# !=
# <=
# >=

# %%
3 == 9 or 4 == 4
# Out:
# True

# %%
animals[1] = 'mar'

# %%
animals[1] = 'mamad'

# %% [markdown]
# if

# %%
if animals[1] == 'mar':
    print("The second animal is a mar")
elif animals[1] == 'asb':
    print("The second animal is an asb")
else:
    print("The second animal is not a mar or asb")
# Out:
# The second animal is not a mar or asb

# %% [markdown]
# for

# %%
animals
# Out:
# ['cat', 'mamad', 'rabbit', 'khar', 23, 3.14, [1, 2, 3], 'hamster', 'hamster']

# %%
numbers = [1, 2, 3, 4, 5]

# %%
for adad in numbers:
    result = adad + 10
    print(result)
# Out:
# 11
# 12
# 13
# 14
# 15

# %%
phone_book.items()
# Out:
# dict_items([('Alice', '123-456-7890'), ('Bob', '987-654-3210'), ('Charlie', '555-555-5555')])

# %%
a ,b = 23, 45
b
# Out:
# 45

# %%
for i in 'mamad':
    print(i)
# Out:
# m
# a
# m
# a
# d

# %% [markdown]
# while

# %%
count = 0
while count <= 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
